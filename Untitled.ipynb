# %%
import os
import csv
import subprocess as sub
import re

# %%
os.chdir('/home/hoseki/Desktop/Sysbio/cSTING/abierta-rep1/crop-200/fel/new/trajs/') 

ab1 = open("abierta_rep1_time.txt", "w") 
ind_ab1 = {0: "6.181",3: "4.394",6: "4.394",8: "3.349",9: "4.394",10: "6.181",14: "6.181",
           21: "4.394",22: "6.181",29: "2.607",34: "3.349",36: "3.349",40: "2.607",
           42: "3.349",44: "3.349",53: "4.394",55: "3.349",60: "6.181",63: "4.394",
           64:"4.394",65: "2.607",66: "1.165",68: "1.562",86: "2.607",91: "4.394",
           93: "3.349",97: "3.349",103: "4.394",110: "1.165",113: "4.394",122: "6.181",
           123: "6.181",129: "3.349",132: "3.349",135: "4.394",136: "6.181",139: "6.181",
           144:"2.607",151: "4.394",154: "2.607",162: "4.394",172: "3.349",173: "6.181",
           174: "2.607",179: "2.607",181: "3.349",184: "6.181",186: "6.181",190: "4.394",
           194: "6.181",195: "3.349",200: "6.181",205: "3.349",208: "2.607",209:"6.181",
           217: "4.394",218: "6.181",222: "4.394",224: "2.607",225: "6.181",226: "4.394",
           228: "6.181",239: "0.000",258: "4.394"}
pattern = re.compile("2 STING_CHICK in water")

for i in ind_ab1:
    for line in open("abierta1-test"+str(i)+".gro"):
        for match in re.finditer(pattern, line):
            ab1.write("energy = "+str(ind_ab1[i])+line)

ab1.close()

# %%
os.chdir('/home/hoseki/Desktop/Sysbio/cSTING/abierta-rep2/fel/new/trajs/') 

ab2 = open("abierta_rep2_time.txt", "w") 
ind_ab2 = {0:"4.618",1:"4.618",3:"2.832",5:"4.618",6:"4.618",10:"0.470",13:"2.832",
           14:"0.470",24:"0.000",28:"4.618",39:"2.832",41:"4.618",43:"1.787",53:"2.832",
           62:"1.045",65:"2.832",69:"1.787",75:"1.787",76:"2.832",79:"1.787",81:"1.787",
           90:"1.045",95:"2.832",100:"0.470",104:"2.832",106:"1.045",108:"4.618",110:"2.832",
           116:"2.832",118:"2.832",123:"1.787",127:"2.832",130:"4.618",131:"2.832",134:"1.787",
           139:"4.618",143:"4.618",144:"4.618",145:"1.045",147:"4.618",150:"4.618",151:"2.832",
           152:"2.832",155:"2.832",167:"2.832",170:"4.618",171:"4.618",172:"4.618",173:"2.832",
           180:"2.832",182:"4.618",190:"1.787",191:"2.832",195:"2.832",197:"2.832",199:"1.045",
           203:"1.787",213:"1.787",217:"1.045",219:"1.787",227:"1.045",237:"2.832",251:"1.787",
           256:"1.045",260:"1.787",265:"2.832",267:"1.787",274:"2.832",276:"4.618",277:"2.832",
           285:"2.832",289:"4.618",291:"2.832",292:"2.832",294:"2.832",307:"2.832",311:"2.832",
           315:"4.618",316:"4.618",317:"4.618",318:"4.618"}
pattern = re.compile("2 STING_CHICK in water")

for i in ind_ab2:
    for line in open("abierta2-test"+str(i)+".gro"):
        for match in re.finditer(pattern, line):
            ab2.write("energy = "+str(ind_ab2[i])+line)

ab2.close()

# %%
os.chdir('/home/hoseki/Desktop/Sysbio/cSTING/cerrada-rep1/prod/fel/new/trajs/') 

cl1 = open("cerrada_rep1_time.txt", "w") 
ind_cl1 = {2:"6.181",4:"4.394",6:"4.394",8:"6.181",9:"2.607",15:"3.349",17:"4.394",21:"3.349",
           22:"4.394",23:"6.181",24:"4.394",25:"2.032",29:"3.349",30:"6.181",35:"1.562",
           41:"4.394",42:"3.349",50:"3.349",53:"1.562",55:"2.607",64:"6.181",66:"4.394",
           68:"6.181",78:"4.394",81:"6.181",82:"3.349",83:"6.181",84:"6.181",86:"1.562",
           90:"6.181",91:"3.349",93:"6.181",95:"4.394",98:"6.181",100:"6.181",101:"6.181",
           104:"4.394",106:"2.607",110:"4.394",113:"4.394",115:"4.394",118:"4.394",119:"3.349",
           122:"4.394",125:"2.607",128:"6.181",129:"6.181",131:"4.394",132:"6.181",133:"6.181",
           134:"6.181",135:"6.181",136:"6.181",138:"6.181",139:"6.181",140:"4.394",142:"3.349",
           147:"3.349",151:"6.181",156:"4.394",162:"6.181",163:"6.181",177:"1.562",180:"2.032",
           183:"4.394",185:"4.394",188:"2.607",194:"0.000",200:"2.607",202:"4.394",203:"6.181",
           207:"2.032",215:"4.394",228:"3.349",233:"4.394",236:"3.349",238:"3.349",241:"2.607",
           247:"4.394",264:"6.181",265:"4.394",266:"4.394",268:"6.181",269:"6.181",271:"6.181"}
pattern = re.compile("2 STING_CHICK in water")

for i in ind_cl1:
    for line in open("cerrada1-test"+str(i)+".gro"):
        for match in re.finditer(pattern, line):
            cl1.write("energy = "+str(ind_cl1[i])+line)
cl1.close()

# %%
os.chdir('/home/hoseki/Desktop/Sysbio/cSTING/cerrada-rep2/fel/new/trajs/') 

cl2 = open("cerrada_rep2_time.txt", "w") 
ind_cl2 = {}
pattern = re.compile("2 STING_CHICK in water")

for i in ind_cl2:
    for line in open("cerrada2-test"+str(i)+".gro"):
        for match in re.finditer(pattern, line):
            cl2.write("energy = "+str(ind_cl2[i])+line)
cl2.close()
